# %%
from numpy import *

print('Welcome to Rock, Paper, Scissors, Spock, Lizard!')
print('To choose your move, enter a number 1-5 respectively')
print('')

ROCK, PAPER, SCISSORS, SPOCK, LIZARD = 1,2,3,4,5
R,P,SC,SP,L=ROCK, PAPER, SCISSORS, SPOCK, LIZARD #Alternative way to type choice
Moves=array([ROCK, PAPER, SCISSORS, SPOCK, LIZARD])

W1='Player One Wins'
W2='Computer Wins'

i=1
while i <= 1:
    
    def WinnerLoser(Player1, Player2):
        WinnerLoser=2
        if Player1==Player2:
            print("It's a tie!")
            print('')
            WinnerLoser=1

        elif (Player1==3 or Player2==3) and (Player1==2 or Player2==2):
            if Player1-Player2==1:
                print(W1+' [scissors cuts paper]')
            else:
                print(W2+' [scissors cuts paper]')

        elif (Player1==2 or Player2==2) and (Player1==1 or Player2==1):
            if Player1-Player2==1:
                print(W1+' [paper covers rock]')
            else:
                print(W2+' [paper covers rock]')    

        elif (Player1==1 or Player2==1) and (Player1==5 or Player2==5):
            if Player1-Player2==-4:
                print(W1+' [rock crushes lizard]')
            else:
                print(W2+' [rock crushes lizard]') 

        elif (Player1==5 or Player2==5) and (Player1==4 or Player2==4):
            if Player1-Player2==1:
                print(W1+' [lizard poisons Spock]')
            else:
                print(W2+' [lizard poisons Spock]')

        elif (Player1==4 or Player2==4) and (Player1==3 or Player2==3):
            if Player1-Player2==1:
                print(W1+' [Spock smashes scissors]')
            else:
                print(W2+' [Spock smashes scissors]')

        elif (Player1==3 or Player2==3) and (Player1==5 or Player2==5):
            if Player1-Player2==-2:
                print(W1+' [scissors decapitates lizard]')
            else:
                print(W2+' [scissors decapitates lizard]')

        elif (Player1==5 or Player2==5) and (Player1==2 or Player2==2):
            if Player1-Player2==3:
                print(W1+' [lizard eats paper]')
            else:
                print(W2+' [lizard eats paper]')

        elif (Player1==2 or Player2==2) and (Player1==4 or Player2==4):
            if Player1-Player2==-2:
                print(W1+' [paper disproves Spock]')
            else:
                print(W2+' [paper disproves Spock]')

        elif (Player1==1 or Player2==1) and (Player1==4 or Player2==4):
            if Player1-Player2==3:
                print(W1+' [Spock vaporizes rock]')
            else:
                print(W2+' [Spock vaporizes rock]')

        elif (Player1==1 or Player2==1) and (Player1==3 or Player2==3):
            if Player1-Player2==-2:
                print(W1+' [rock crushes scissors]')
            else:
                print(W2+' [rock crushes scissors]')

        while True:
            if Player1 != Player2:
                try:
                    print('')
                    Y=y=yes=Yes=yEs=YES=yeS=YEs=yES=YeS= 1
                    N=n=no=NO=No=nO =0
                    Again=eval(input('Would you like to play again? {Y/N}: '))
                    if Again == 1:
                        print('')
                        WinnerLoser = 1
                        break
                    elif Again == 0:
                        WinnerLoser = 2
                        break
                    else:
                        raise ValueError
                except ValueError:
                    print('Invalid choice')
                    continue
                except NameError:
                    print('Not a valid option')
                    continue
                except SyntaxError:
                    print('Not a valid option [SyntaxError]')
                    continue
                break
            elif Player1==Player2:
                break
        return WinnerLoser

    while True:
        try:
            Player1=eval(input('Enter your choice {1-5}: '))
            i = 2
            while Player1 not in Moves:
                print('Not a valid move')
                Player1=eval(input('Enter your choice {1-5}: '))
        except NameError:
            print('Not a valid move, check your spelling/capitalization')
            print('')
            i = 1
            continue
        except SyntaxError:
            print('Not a valid option [SyntaxError]')
            i = 1
            continue
        break
            
    Player2=random.randint(1,6)
    Moves2=array(['Rock', 'Paper', 'Scissors', 'Spock', 'Lizard'])
    print('Your opponent chose %s' %(Moves2[Player2 - 1]))

    WL=WinnerLoser(Player1,Player2)
    
    if WL==1:
        i = 1
    elif WL==2:
        i = 2
# Out:
# Welcome to Rock, Paper, Scissors, Spock, Lizard!
# To choose your move, enter a number 1-5 respectively
#
# Enter your choice {1-5}: 3
# Your opponent chose Spock
# Computer Wins [Spock smashes scissors]
#
# Would you like to play again? {Y/N}: n

# %%
from pylab import *
from numpy import *

ComputerTie=[]

Computer1Win=[]
Computer2Win=[]

Computer1Moves=[]

def WinnerLoser2(Computer1,Computer2):
    if Computer1==Computer2:
        ComputerTie.append(3)
        WinnerLoser2=3

    elif (Computer1==3 or Computer2==3) and (Computer1==2 or Computer2==2):
        if Computer1-Computer2==1:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2

    elif (Computer1==2 or Computer2==2) and (Computer1==1 or Computer2==1):
        if Computer1-Computer2==1:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2

    elif (Computer1==1 or Computer2==1) and (Computer1==5 or Computer2==5):
        if Computer1-Computer2==-4:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2

    elif (Computer1==5 or Computer2==5) and (Computer1==4 or Computer2==4):
        if Computer1-Computer2==1:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2

    elif (Computer1==4 or Computer2==4) and (Computer1==3 or Computer2==3):
        if Computer1-Computer2==1:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2

    elif (Computer1==3 or Computer2==3) and (Computer1==5 or Computer2==5):
        if Computer1-Computer2==-2:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2

    elif (Computer1==5 or Computer2==5) and (Computer1==2 or Computer2==2):
        if Computer1-Computer2==3:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2

    elif (Computer1==2 or Computer2==2) and (Computer1==4 or Computer2==4):
        if Computer1-Computer2==-2:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2

    elif (Computer1==1 or Computer2==1) and (Computer1==4 or Computer2==4):
        if Computer1-Computer2==3:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2

    elif (Computer1==1 or Computer2==1) and (Computer1==3 or Computer2==3):
        if Computer1-Computer2==-2:
            Computer1Win.append(1)
            WinnerLoser2=1
        else:
            Computer2Win.append(2)
            WinnerLoser2=2
    return WinnerLoser2

for K in range(1000):
    Computer1=random.randint(1,6)
    Computer1Moves.append(Computer1)
    Computer2=random.randint(1,6)
    WinnerLoser2(Computer1,Computer2)

fig1 = figure(figsize=(10,10));
rcParams.update({'font.size': 20})
x = [0,10,20]
y = [len(ComputerTie),len(Computer1Win),len(Computer2Win)]
title('Outcome Of %d Matches' %(len(ComputerTie+Computer1Win+Computer2Win)))
xlabel('Match Outcome', fontsize=25)
ylabel('Number of Matches', fontsize=25)
xticks([])

CC=array(['red','blue','green'])
CC2=array(['black','brown','teal','orange','magenta'])
LL=array(['Ties','Computer1 Wins','Computer2 Wins'])
for P in range(3):
    bar(x[P],y[P],5,align='center',label=LL[P],color=CC[P])
    annotate(y[P], xy=(x[P], y[P]+1), fontsize=15, va='bottom', ha='center')
legend(loc='upper left',fontsize=18)
#savefig('Henry_Wahhab_Homework5_MatchOutcome.png', bbox_inches = 'tight')



fig2 = figure(figsize=(10,10));
rcParams.update({'font.size': 20})
x2 = [0,10,20,30,40]
y2 = [Computer1Moves.count(1),Computer1Moves.count(2),Computer1Moves.count(3),Computer1Moves.count(4),Computer1Moves.count(5)]
title('Moves Chosen By Computer1')
xlabel('Move Selection', fontsize=25)
ylabel('Times Used', fontsize=25)
xticks([])

MM=array(['Rock','Paper','Scissors','Spock','Lizard'])
for B in range(5):
    bar(x2[B],y2[B],5,align='center',label=MM[B],color=CC2[B])
    annotate(y2[B], xy=(x2[B], y2[B]+1), fontsize=15, va='bottom', ha='center')
legend(loc='lower center',fontsize=18)
#savefig('Henry_Wahhab_Homework5_Computer1Moves.png', bbox_inches = 'tight')
